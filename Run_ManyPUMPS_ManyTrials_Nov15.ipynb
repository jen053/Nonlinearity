# %%
from numpy import *
from pylab import *
import string

from datetime import date

import AgilentSCPI
import time
import numpy as np
import sys
import matplotlib.pyplot as plt
import time

# %%
delayvec=np.arange(0,100,1)
n_aves=4096
t_delay=n_aves*2e-3 #2 ms between pulses


#addtodelay=45 #sample 2; or 1 and 2
#addtodelay=43.5 #sample 3; or 1 and or 2
addtodelay=48 #sampleA_COS; or 1 and or 2


print t_delay
fname_root="/Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/"
AMP=[10.0]
Ntrials=10
# Out:
# 8.192
# 8.192

# %%
class timedata:

    def __init__(self, name):
        self.name = name
        self.time = np.array    # creates a new empty list
        self.data = np.array    # creates a new empty list

# %%
def readlabdat(fname,dataset):
# read in data from the scope and make a matrix of values from it
    
    
    f = open(fname,'r')
    #header1=f.readline()
    #header2=f.readline()
    tmp1=[]
    tmp2=[]
    
    for line in f:
        columns = line.split(',')
        tmp1.append(float(columns[0]))
        tmp2.append(float(columns[1]))

    dataset.time=np.asarray(tmp1)
    dataset.data=np.asarray(tmp2)
    f.close()

# %%
# read data from oscilloscope and save to file
def saveWave(filename,chs,npts='MAXIMUM'):
    for ch in chs:
        p1,x1 = osc.OscRead2Numpy(ch,npts)
        if 'data' in locals():
            data = vstack((data,x1))
        else:
            data = x1
            
    
    t = arange(len(x1))*p1[4] + p1[5]
    data = vstack((t,data)).T
    savetxt(filename, data, fmt="%12.6G", delimiter=',')
    print shape(data), "data points saved to "+filename

# %% [markdown]
# Setup Function Generator

# %%
funcgen = AgilentSCPI.SCPI("134.153.36.84")
q=funcgen.query('*IDN?\n')
print q
setupFile="STATE_COSJ20"
cmd = ":MMEMory:LOAD:STATe 'INT:\\"+setupFile+"'\n"
funcgen.s.send(cmd)
# funcgen.s.send(":SOUR2:VOLT"+" "+str(AMP[0])+"\n")
# funcgen.s.send(":SOUR1:VOLT"+" 5.0"+"\n")
#this sets up the amplitudes and frequency of the pump (on channel 2) and probe (on channel 1)
funcgen.s.send(":SOUR2:VOLT"+" "+str(AMP[0])+"\n")
funcgen.s.send(":SOUR2:FREQ"+" "+str(50000)+"\n")

funcgen.s.send(":SOUR1:VOLT"+" "+str(1)+"\n")
funcgen.s.send(":SOUR1:FREQ"+" "+str(500000)+"\n")
# Out:
# Agilent Technologies,33510B,MY52202006,5.02-1.19-2.00-58-00
#
# Agilent Technologies,33510B,MY52202006,5.02-1.19-2.00-58-00
# 19
# 19

# %% [markdown]
# Setup Oscilloscope

# %%
osc = AgilentSCPI.SCPI("134.153.36.86")
q2=osc.query('*IDN?\n')
print q2
osc.reset()
osc.s.send(":TRIGger:EDGE:SOURCe EXTernal\n")
osc.s.send(":TRIGger:EDGE:LEVel 5.0\n")
osc.s.send(":TRIGger:EDGE:SLOPe POSitive\n")
osc.s.send(":TIM:REF LEFT\n")
osc.s.send(":TIM:DEL "+ str(addtodelay)+"us\n")
osc.s.send(":TIM:SCAL 1.0us\n")  #time scale 
osc.s.send(":CHANnel1:SCALe 0.01\n") # Vertical axis limit of probe 
osc.s.send(":CHANnel2:SCALe 20\n") #Vertical axis limit of pump
osc.s.send(":ACQuire:TYPE AVERage\n")
osc.s.send(":ACQuire:COUNt 4096\n")
#fname=fname_root+"junk.csv"
#saveWave(fname,[1])

#Do not put anything in this box below the current line
# addtodelay_=48
# delay_=1
# cmd_=":TRIG:DEL "+str(delay_)+"us\n"
# funcgen.s.send(cmd_)
# funcgen.s.send(":SOUR1:VOLT"+" "+str(5)+"\n") #*****
# funcgen.s.send(":OUTP1 ON\n")#*****
# funcgen.s.send(":OUTP2 ON\n") #*****
# osc.s.send(":TIM:DEL "+ str(addtodelay_+delay_)+"us\n")#*****
# Out:
# AGILENT TECHNOLOGIES,MSO-X 2014A,MY56040367,02.50.2019022736
#
# AGILENT TECHNOLOGIES,MSO-X 2014A,MY56040367,02.50.2019022736
# 20
# 20

# %%
for itrial in range(Ntrials):
    for ampval in AMP:
        funcgen.s.send(":SOUR2:VOLT"+" "+str(ampval)+"\n")
        funcgen.s.send(":OUTP1 ON\n")
        funcgen.s.send(":OUTP2 ON\n")
        cmd=":TRIG:DEL "+str(0)+"us\n"
        funcgen.s.send(cmd)
        fname_root_add=fname_root+"Trial"+str(itrial+1)+"/"+str(ampval)+"V/"
        fname=fname_root_add+str("STrans_B4.csv")
        osc.s.send(":TIM:REF LEFT\n")
        osc.s.send(":TIM:SCAL 20us\n")
        osc.s.send(":TIM:DEL 30us\n")
        osc.s.send("CHANnel2:SCALe 25\n")
        saveWave(fname,[2])
        osc.s.send(":TIM:SCAL 1.0us\n")
        scaldel=1
        for delay in delayvec:
            #set delay
#            cmd=":TRIG2:DEL "+str(delay)+"us\n"
            cmd=":TRIG:DEL "+str(delay)+"us\n"
            funcgen.s.send(cmd)
    
            osc.s.send(":TIM:DEL "+ str(addtodelay+delay)+"us\n")
 #           osc.s.send(":TIM:DEL "+ str(addtodelay)+"us\n")

            #record probe only
            funcgen.s.send(":OUTP1 ON\n") #probe on
            funcgen.s.send(":OUTP2 OFF\n") #PUMP off

            time.sleep(t_delay)

            fname=fname_root_add+"pr"+str(int(scaldel*delay))+".csv"
            saveWave(fname,[1])

            #record PUMP only
            osc.s.send(":TIM:DEL "+ str(addtodelay+delay)+"us\n")
  #          osc.s.send(":TIM:DEL "+ str(addtodelay)+"us\n")
            funcgen.s.send(":OUTP1 OFF\n") #probe on
            funcgen.s.send(":OUTP2 ON\n") #PUMP off
            time.sleep(t_delay)

            fname=fname_root_add+"pu"+str(int(scaldel*delay))+".csv"
            saveWave(fname,[1])

            #record PUMP and probe
            osc.s.send(":TIM:DEL "+ str(addtodelay+delay)+"us\n")
            #osc.s.send(":TIM:DEL "+ str(addtodelay)+"us\n")
            funcgen.s.send(":OUTP1 ON\n") #probe on
            funcgen.s.send(":OUTP2 ON\n") #PUMP off
            time.sleep(t_delay)

            fname=fname_root_add+"pp"+str(int(scaldel*delay))+".csv"
            saveWave(fname,[1])

funcgen.s.send(":OUTP1 OFF\n")
funcgen.s.send(":OUTP2 OFF\n")
# Out:
# (7679, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/STrans_B4.csv
# (7679, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/STrans_B4.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr0.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr0.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu0.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu0.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp0.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp0.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr1.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr1.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu1.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu1.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp1.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp1.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr2.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr2.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu2.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu2.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp2.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp2.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr3.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr3.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu3.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu3.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp3.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp3.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr4.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr4.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu4.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu4.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp4.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp4.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr5.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr5.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu5.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu5.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp5.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp5.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr6.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr6.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu6.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu6.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp6.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp6.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr7.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr7.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu7.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu7.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp7.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp7.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr8.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr8.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu8.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu8.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp8.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp8.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr9.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr9.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu9.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu9.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp9.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp9.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr10.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr10.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu10.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu10.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp10.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp10.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr11.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr11.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu11.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu11.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp11.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp11.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr12.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr12.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu12.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu12.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp12.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp12.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr13.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr13.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu13.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu13.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp13.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp13.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr14.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr14.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu14.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu14.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp14.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp14.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr15.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr15.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu15.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu15.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp15.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp15.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr16.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr16.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu16.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu16.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp16.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp16.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr17.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr17.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu17.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu17.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp17.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp17.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr18.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr18.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu18.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu18.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp18.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp18.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr19.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr19.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu19.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu19.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp19.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp19.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr20.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr20.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu20.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu20.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp20.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp20.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr21.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr21.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu21.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu21.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp21.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp21.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr22.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr22.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu22.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu22.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp22.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp22.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr23.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr23.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu23.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu23.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp23.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp23.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr24.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr24.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu24.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu24.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp24.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp24.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr25.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr25.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu25.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu25.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp25.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp25.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr26.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr26.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu26.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu26.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp26.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp26.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr27.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr27.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu27.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu27.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp27.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp27.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr28.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr28.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu28.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu28.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp28.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp28.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr29.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr29.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu29.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu29.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp29.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp29.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr30.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr30.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu30.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu30.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp30.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp30.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr31.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr31.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu31.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu31.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp31.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp31.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr32.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr32.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu32.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu32.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp32.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp32.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr33.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr33.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu33.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu33.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp33.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp33.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr34.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr34.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu34.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu34.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp34.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp34.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr35.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr35.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu35.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu35.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp35.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp35.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr36.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr36.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu36.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu36.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp36.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp36.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr37.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr37.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu37.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu37.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp37.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp37.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr38.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr38.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu38.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu38.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp38.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp38.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr39.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr39.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu39.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu39.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp39.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp39.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr40.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr40.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu40.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu40.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp40.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp40.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr41.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr41.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu41.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu41.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp41.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp41.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr42.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr42.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu42.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu42.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp42.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp42.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr43.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr43.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu43.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu43.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp43.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp43.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr44.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr44.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu44.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu44.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp44.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp44.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr45.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr45.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu45.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu45.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp45.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp45.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr46.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr46.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu46.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu46.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp46.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp46.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr47.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr47.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu47.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu47.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp47.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp47.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr48.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr48.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu48.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu48.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp48.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp48.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr49.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr49.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu49.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu49.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp49.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp49.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr50.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr50.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu50.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu50.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp50.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp50.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr51.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr51.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu51.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu51.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp51.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp51.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr52.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr52.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu52.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu52.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp52.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp52.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr53.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr53.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu53.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu53.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp53.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp53.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr54.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr54.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu54.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu54.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp54.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp54.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr55.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pr55.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu55.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pu55.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp55.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial1/10.0V/pp55.csv
# ...
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu84.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu84.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp84.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp84.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr85.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr85.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu85.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu85.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp85.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp85.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr86.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr86.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu86.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu86.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp86.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp86.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr87.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr87.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu87.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu87.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp87.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp87.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr88.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr88.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu88.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu88.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp88.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp88.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr89.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr89.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu89.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu89.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp89.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp89.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr90.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr90.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu90.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu90.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp90.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp90.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr91.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr91.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu91.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu91.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp91.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp91.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr92.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr92.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu92.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu92.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp92.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp92.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr93.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr93.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu93.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu93.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp93.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp93.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr94.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr94.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu94.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu94.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp94.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp94.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr95.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr95.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu95.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu95.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp95.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp95.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr96.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr96.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu96.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu96.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp96.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp96.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr97.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr97.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu97.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu97.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp97.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp97.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr98.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr98.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu98.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu98.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp98.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp98.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr99.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pr99.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu99.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pu99.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp99.csv
# (2500, 2) data points saved to /Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial2/10.0V/pp99.csv
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-8-9d045075f10d> in <module>()
#      12         osc.s.send(":TIM:DEL 30us\n")
#      13         osc.s.send("CHANnel2:SCALe 25\n")
# ---> 14         saveWave(fname,[2])
#      15         osc.s.send(":TIM:SCAL 1.0us\n")
#      16         scaldel=1
#
# <ipython-input-5-47852e388493> in saveWave(filename, chs, npts)
#      11     t = arange(len(x1))*p1[4] + p1[5]
#      12     data = vstack((t,data)).T
# ---> 13     savetxt(filename, data, fmt="%12.6G", delimiter=',')
#      14     print shape(data), "data points saved to "+filename
#
# /Users/jacobnewman/anaconda2/lib/python2.7/site-packages/numpy/lib/npyio.pyc in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1305     if _is_string_like(fname):
#    1306         # datasource doesn't support creating a new file ...
# -> 1307         open(fname, 'wt').close()
#    1308         fh = np.lib._datasource.open(fname, 'wt', encoding=encoding)
#    1309         own_fh = True
#
# IOError: [Errno 2] No such file or directory: '/Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial3/10.0V/STrans_B4.csv'
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-8-9d045075f10d> in <module>()
#      12         osc.s.send(":TIM:DEL 30us\n")
#      13         osc.s.send("CHANnel2:SCALe 25\n")
# ---> 14         saveWave(fname,[2])
#      15         osc.s.send(":TIM:SCAL 1.0us\n")
#      16         scaldel=1
#
# <ipython-input-5-47852e388493> in saveWave(filename, chs, npts)
#      11     t = arange(len(x1))*p1[4] + p1[5]
#      12     data = vstack((t,data)).T
# ---> 13     savetxt(filename, data, fmt="%12.6G", delimiter=',')
#      14     print shape(data), "data points saved to "+filename
#
# /Users/jacobnewman/anaconda2/lib/python2.7/site-packages/numpy/lib/npyio.pyc in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1305     if _is_string_like(fname):
#    1306         # datasource doesn't support creating a new file ...
# -> 1307         open(fname, 'wt').close()
#    1308         fh = np.lib._datasource.open(fname, 'wt', encoding=encoding)
#    1309         own_fh = True
#
# IOError: [Errno 2] No such file or directory: '/Users/jacobnewman/Documents/Jacob/MSc./DATA/SampleA_COS/Transducer_deconnect_study/Run2/Trial3/10.0V/STrans_B4.csv'

# %%
cmd=":TRIG2:DEL "+str(delay)+"us\n"
funcgen.s.send(cmd)
